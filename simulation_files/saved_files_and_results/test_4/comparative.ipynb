# %%
import pandas
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import numpy as np
from IPython import get_ipython
import math


get_ipython().run_line_magic('matplotlib', 'inline')

# %%
#### Solo hay que modificar estos dos parámetros  #####
test = 4     # test number
num_simu = 5 # number of simulations 

####################################################
path_folder = "/home/miguel/catkin_ws/src/simulation_files/saved_files_and_results/test_" + str(test) + "/"
path_folder
# Out:
# '/home/miguel/catkin_ws/src/simulation_files/saved_files_and_results/test_4/'

# %%
all_simu_RGB = list()
all_simu_hybrid = list()
for i in range(1, num_simu +1):
    path_RGB = path_folder + "simu_" + str(i) + "/zzz_result_marker.txt"
    path_hybrid = path_folder + "simu_" + str(i) + "/zzz_result_hybrid.txt"
    
    data_RGB = pandas.read_csv(path_RGB, skipinitialspace = True)
    data_hybrid = pandas.read_csv(path_hybrid, skipinitialspace = True)
    
    all_simu_RGB.append(data_RGB)
    all_simu_hybrid.append(data_hybrid)
    
all_simu_hybrid[1].head()
# Out:
#    mean X error  mean Y error  mean Distance error  mean YAW error  \
# 0         0.203         0.204                0.294           1.332
#
#    mean X deviation  mean Y deviation  max X error  max Y error  \
# 0             0.192             0.178        0.353        0.473
#
#    max Distance error  max YAW error  max X deviation  max Y deviation  \
# 0               0.565           6.71            0.515            0.446
#
#    min X error  min Y error  min Distance error  min YAW error  \
# 0        0.039        0.003               0.045          0.022
#
#    min X deviation  min Y deviation
# 0            0.048             0.03

# %%
###### mean #####
mean_x_error_laser = 0
mean_x_error_RGB = 0
mean_x_error_hybrid = 0

mean_y_error_laser = 0
mean_y_error_RGB = 0
mean_y_error_hybrid = 0

mean_distance_error_laser = 0
mean_distance_error_RGB = 0
mean_distance_error_hybrid = 0

mean_yaw_error_laser = 0
mean_yaw_error_RGB = 0
mean_yaw_error_hybrid = 0

mean_x_deviation_laser = 0
mean_x_deviation_RGB = 0
mean_x_deviation_hybrid = 0

mean_y_deviation_laser = 0
mean_y_deviation_RGB = 0
mean_y_deviation_hybrid = 0

######### max ######
max_x_error_laser = 0
max_x_error_RGB = 0
max_x_error_hybrid = 0

max_y_error_laser = 0
max_y_error_RGB = 0
max_y_error_hybrid = 0

max_distance_error_laser = 0
max_distance_error_RGB = 0
max_distance_error_hybrid = 0

max_yaw_error_laser = 0
max_yaw_error_RGB = 0
max_yaw_error_hybrid = 0

max_x_deviation_laser = 0
max_x_deviation_RGB = 0
max_x_deviation_hybrid = 0

max_y_deviation_laser = 0
max_y_deviation_RGB = 0
max_y_deviation_hybrid = 0

######### min ######
min_x_error_laser = 0
min_x_error_RGB = 0
min_x_error_hybrid = 0

min_y_error_laser = 0
min_y_error_RGB = 0
min_y_error_hybrid = 0

min_distance_error_laser = 0
min_distance_error_RGB = 0
min_distance_error_hybrid = 0

min_yaw_error_laser = 0
min_yaw_error_RGB = 0
min_yaw_error_hybrid = 0

min_x_deviation_laser = 0
min_x_deviation_RGB = 0
min_x_deviation_hybrid = 0

min_y_deviation_laser = 0
min_y_deviation_RGB = 0
min_y_deviation_hybrid = 0

for i in range (0, num_simu):
    #mean_x_error_laser += all_simu_laser[i]["mean X error"]
    mean_x_error_RGB += all_simu_RGB[i]["mean X error"]
    mean_x_error_hybrid += all_simu_hybrid[i]["mean X error"]
    
    #mean_y_error_laser += all_simu_laser[i]["mean Y error"]
    mean_y_error_RGB += all_simu_RGB[i]["mean Y error"]
    mean_y_error_hybrid += all_simu_hybrid[i]["mean Y error"]
    
    #mean_distance_error_laser += all_simu_laser[i]["mean Distance error"]
    mean_distance_error_RGB += all_simu_RGB[i]["mean Distance error"]
    mean_distance_error_hybrid += all_simu_hybrid[i]["mean Distance error"]
    
    #mean_yaw_error_laser += all_simu_laser[i]["mean YAW error"]
    mean_yaw_error_RGB += all_simu_RGB[i]["mean YAW error"]
    mean_yaw_error_hybrid += all_simu_hybrid[i]["mean YAW error"]
    
    #mean_x_deviation_laser += all_simu_laser[i]["mean X deviation"]
    mean_x_deviation_RGB += all_simu_RGB[i]["mean X deviation"]
    mean_x_deviation_hybrid += all_simu_hybrid[i]["mean X deviation"]
    
    #mean_y_deviation_laser += all_simu_laser[i]["mean Y deviation"]
    mean_y_deviation_RGB += all_simu_RGB[i]["mean Y deviation"]
    mean_y_deviation_hybrid += all_simu_hybrid[i]["mean Y deviation"]
    
    ##### max #####
    #max_x_error_laser += all_simu_laser[i]["max X error"]
    max_x_error_RGB += all_simu_RGB[i]["max X error"]
    max_x_error_hybrid += all_simu_hybrid[i]["max X error"]
    
    #max_y_error_laser += all_simu_laser[i]["max Y error"]
    max_y_error_RGB += all_simu_RGB[i]["max Y error"]
    max_y_error_hybrid += all_simu_hybrid[i]["max Y error"]
    
    #max_distance_error_laser += all_simu_laser[i]["max Distance error"]
    max_distance_error_RGB += all_simu_RGB[i]["max Distance error"]
    max_distance_error_hybrid += all_simu_hybrid[i]["max Distance error"]
    
    #max_yaw_error_laser += all_simu_laser[i]["max YAW error"]
    max_yaw_error_RGB += all_simu_RGB[i]["max YAW error"]
    max_yaw_error_hybrid += all_simu_hybrid[i]["max YAW error"]
    
    #max_x_deviation_laser += all_simu_laser[i]["max X deviation"]
    max_x_deviation_RGB += all_simu_RGB[i]["max X deviation"]
    max_x_deviation_hybrid += all_simu_hybrid[i]["max X deviation"]
    
    #max_y_deviation_laser += all_simu_laser[i]["max Y deviation"]
    max_y_deviation_RGB += all_simu_RGB[i]["max Y deviation"]
    max_y_deviation_hybrid += all_simu_hybrid[i]["max Y deviation"]
    
    ##### min #####
    #min_x_error_laser += all_simu_laser[i]["min X error"]
    min_x_error_RGB += all_simu_RGB[i]["min X error"]
    min_x_error_hybrid += all_simu_hybrid[i]["min X error"]
    
    #min_y_error_laser += all_simu_laser[i]["min Y error"]
    min_y_error_RGB += all_simu_RGB[i]["min Y error"]
    min_y_error_hybrid += all_simu_hybrid[i]["min Y error"]
    
    #min_distance_error_laser += all_simu_laser[i]["min Distance error"]
    min_distance_error_RGB += all_simu_RGB[i]["min Distance error"]
    min_distance_error_hybrid += all_simu_hybrid[i]["min Distance error"]
    
    #min_yaw_error_laser += all_simu_laser[i]["min YAW error"]
    min_yaw_error_RGB += all_simu_RGB[i]["min YAW error"]
    min_yaw_error_hybrid += all_simu_hybrid[i]["min YAW error"]
    
    #min_x_deviation_laser += all_simu_laser[i]["min X deviation"]
    min_x_deviation_RGB += all_simu_RGB[i]["min X deviation"]
    min_x_deviation_hybrid += all_simu_hybrid[i]["min X deviation"]
    
    #min_y_deviation_laser += all_simu_laser[i]["min Y deviation"]
    min_y_deviation_RGB += all_simu_RGB[i]["min Y deviation"]
    min_y_deviation_hybrid += all_simu_hybrid[i]["min Y deviation"]
    
    
#save_file_laser = path_folder + "result_scan2D.txt"
save_file_RGB = path_folder + "result_marker.txt"
save_file_hybrid = path_folder + "result_hybrid.txt"
#comparative_laser = open(save_file_laser, "w")
comparative_RGB = open(save_file_RGB, "w")
comparative_hybrid = open(save_file_hybrid, "w")

"""comparative_laser.write("max X error,max Y error,max Distance error,max YAW error,max X deviation,max Y deviation")
comparative_laser.write(",mean X error,mean Y error,mean Distance error,mean YAW error,mean X deviation,mean Y deviation")
comparative_laser.write(",min X error,min Y error,min Distance error,min YAW error,min X deviation,min Y deviation\n")
comparative_laser.write(str(round((max_x_error_laser[0]/num_simu), 3)) + ",")
comparative_laser.write(str(round((max_y_error_laser[0]/num_simu), 3)) + ",")
comparative_laser.write(str(round((max_distance_error_laser[0]/num_simu), 3)) + ",")
comparative_laser.write(str(round((max_yaw_error_laser[0]/num_simu), 3)) + ",")
comparative_laser.write(str(round((max_x_deviation_laser[0]/num_simu), 3)) + ",")
comparative_laser.write(str(round((max_y_deviation_laser[0]/num_simu), 3)) + ",")

comparative_laser.write(str(round((mean_x_error_laser[0]/num_simu), 3)) + ",")
comparative_laser.write(str(round((mean_y_error_laser[0]/num_simu), 3)) + ",")
comparative_laser.write(str(round((mean_distance_error_laser[0]/num_simu), 3)) + ",")
comparative_laser.write(str(round((mean_yaw_error_laser[0]/num_simu), 3)) + ",")
comparative_laser.write(str(round((mean_x_deviation_laser[0]/num_simu), 3)) + ",")
comparative_laser.write(str(round((mean_y_deviation_laser[0]/num_simu), 3)) + ",")

comparative_laser.write(str(round((min_x_error_laser[0]/num_simu), 3)) + ",")
comparative_laser.write(str(round((min_y_error_laser[0]/num_simu), 3)) + ",")
comparative_laser.write(str(round((min_distance_error_laser[0]/num_simu), 3)) + ",")
comparative_laser.write(str(round((min_yaw_error_laser[0]/num_simu), 3)) + ",")
comparative_laser.write(str(round((min_x_deviation_laser[0]/num_simu), 3)) + ",")
comparative_laser.write(str(round((min_y_deviation_laser[0]/num_simu), 3)))
comparative_laser.close()"""

comparative_RGB.write("max X error,max Y error,max Distance error,max YAW error,max X deviation,max Y deviation")
comparative_RGB.write(",mean X error,mean Y error,mean Distance error,mean YAW error,mean X deviation,mean Y deviation")
comparative_RGB.write(",min X error,min Y error,min Distance error,min YAW error,min X deviation,min Y deviation\n")
comparative_RGB.write(str(round((max_x_error_RGB[0]/num_simu), 3)) + ",")
comparative_RGB.write(str(round((max_y_error_RGB[0]/num_simu), 3)) + ",")
comparative_RGB.write(str(round((max_distance_error_RGB[0]/num_simu), 3)) + ",")
comparative_RGB.write(str(round((max_yaw_error_RGB[0]/num_simu), 3)) + ",")
comparative_RGB.write(str(round((max_x_deviation_RGB[0]/num_simu), 3)) + ",")
comparative_RGB.write(str(round((max_y_deviation_RGB[0]/num_simu), 3)) + ",")

comparative_RGB.write(str(round((mean_x_error_RGB[0]/num_simu), 3)) + ",")
comparative_RGB.write(str(round((mean_y_error_RGB[0]/num_simu), 3)) + ",")
comparative_RGB.write(str(round((mean_distance_error_RGB[0]/num_simu), 3)) + ",")
comparative_RGB.write(str(round((mean_yaw_error_RGB[0]/num_simu), 3)) + ",")
comparative_RGB.write(str(round((mean_x_deviation_RGB[0]/num_simu), 3)) + ",")
comparative_RGB.write(str(round((mean_y_deviation_RGB[0]/num_simu), 3)) + ",")

comparative_RGB.write(str(round((min_x_error_RGB[0]/num_simu), 3)) + ",")
comparative_RGB.write(str(round((min_y_error_RGB[0]/num_simu), 3)) + ",")
comparative_RGB.write(str(round((min_distance_error_RGB[0]/num_simu), 3)) + ",")
comparative_RGB.write(str(round((min_yaw_error_RGB[0]/num_simu), 3)) + ",")
comparative_RGB.write(str(round((min_x_deviation_RGB[0]/num_simu), 3)) + ",")
comparative_RGB.write(str(round((min_y_deviation_RGB[0]/num_simu), 3)))
comparative_RGB.close()

comparative_hybrid.write("max X error,max Y error,max Distance error,max YAW error,max X deviation,max Y deviation")
comparative_hybrid.write(",mean X error,mean Y error,mean Distance error,mean YAW error,mean X deviation,mean Y deviation")
comparative_hybrid.write(",min X error,min Y error,min Distance error,min YAW error,min X deviation,min Y deviation\n")
comparative_hybrid.write(str(round((max_x_error_hybrid[0]/num_simu), 3)) + ",")
comparative_hybrid.write(str(round((max_y_error_hybrid[0]/num_simu), 3)) + ",")
comparative_hybrid.write(str(round((max_distance_error_hybrid[0]/num_simu), 3)) + ",")
comparative_hybrid.write(str(round((max_yaw_error_hybrid[0]/num_simu), 3)) + ",")
comparative_hybrid.write(str(round((max_x_deviation_hybrid[0]/num_simu), 3)) + ",")
comparative_hybrid.write(str(round((max_y_deviation_hybrid[0]/num_simu), 3)) + ",")

comparative_hybrid.write(str(round((mean_x_error_hybrid[0]/num_simu), 3)) + ",")
comparative_hybrid.write(str(round((mean_y_error_hybrid[0]/num_simu), 3)) + ",")
comparative_hybrid.write(str(round((mean_distance_error_hybrid[0]/num_simu), 3)) + ",")
comparative_hybrid.write(str(round((mean_yaw_error_hybrid[0]/num_simu), 3)) + ",")
comparative_hybrid.write(str(round((mean_x_deviation_hybrid[0]/num_simu), 3)) + ",")
comparative_hybrid.write(str(round((mean_y_deviation_hybrid[0]/num_simu), 3)) + ",")

comparative_hybrid.write(str(round((min_x_error_hybrid[0]/num_simu), 3)) + ",")
comparative_hybrid.write(str(round((min_y_error_hybrid[0]/num_simu), 3)) + ",")
comparative_hybrid.write(str(round((min_distance_error_hybrid[0]/num_simu), 3)) + ",")
comparative_hybrid.write(str(round((min_yaw_error_hybrid[0]/num_simu), 3)) + ",")
comparative_hybrid.write(str(round((min_x_deviation_hybrid[0]/num_simu), 3)) + ",")
comparative_hybrid.write(str(round((min_y_deviation_hybrid[0]/num_simu), 3)))
comparative_hybrid.close()

# %%
"""path_laser = path_folder + "result_scan2D.txt"
data_laser = pandas.read_csv(path_laser, skipinitialspace = True)
data_laser.head()"""
# Out:
# 'path_laser = path_folder + "result_scan2D.txt"\ndata_laser = pandas.read_csv(path_laser, skipinitialspace = True)\ndata_laser.head()'

# %%
path_marker = path_folder + "result_marker.txt"
data_marker = pandas.read_csv(path_marker, skipinitialspace = True)
data_marker.head()
# Out:
#    max X error  max Y error  max Distance error  max YAW error  \
# 0        0.337        0.502               0.523          4.552
#
#    max X deviation  max Y deviation  mean X error  mean Y error  \
# 0            0.492            0.577         0.183         0.157
#
#    mean Distance error  mean YAW error  mean X deviation  mean Y deviation  \
# 0                 0.28            1.16             0.282             0.323
#
#    min X error  min Y error  min Distance error  min YAW error  \
# 0        0.003        0.005               0.106          0.041
#
#    min X deviation  min Y deviation
# 0            0.149            0.071

# %%
path_hybrid = path_folder + "result_hybrid.txt"
data_hybrid = pandas.read_csv(path_hybrid, skipinitialspace = True)
data_hybrid.head()
# Out:
#    max X error  max Y error  max Distance error  max YAW error  \
# 0        0.357        0.479                0.55          6.431
#
#    max X deviation  max Y deviation  mean X error  mean Y error  \
# 0              0.5            0.464         0.172         0.203
#
#    mean Distance error  mean YAW error  mean X deviation  mean Y deviation  \
# 0                0.278           1.435             0.211             0.216
#
#    min X error  min Y error  min Distance error  min YAW error  \
# 0        0.016        0.001               0.034          0.013
#
#    min X deviation  min Y deviation
# 0            0.053            0.035

# %%
file = path_folder + "result_percent.txt"
results = open(file, "w")
dec = 2

results.write("### Hybrid values refer to Marker values:\n\n")
results.write("#### mean ####\n")
#results.write("mean X position error_laser: " + str(round(((((mean_x_error_hybrid[0]/num_simu) * 100)/(mean_x_error_laser[0]/num_simu)) - 100), dec)) + "%\n")
results.write("mean X position error_marker: " + str(round(((((mean_x_error_hybrid[0]/num_simu) * 100)/(mean_x_error_RGB[0]/num_simu)) - 100), dec)) + "%\n")
results.write("\n")
#results.write("mean Y position error_laser: " + str(round(((((mean_y_error_hybrid[0]/num_simu) * 100)/(mean_y_error_laser[0]/num_simu)) - 100), dec))  + "%\n")
results.write("mean Y position error_marker: " + str(round(((((mean_y_error_hybrid[0]/num_simu) * 100)/(mean_y_error_RGB[0]/num_simu)) - 100), dec))  + "%\n")
results.write("\n")
#results.write("mean Distance position error_laser: " + str(round(((((mean_distance_error_hybrid[0]/num_simu) * 100)/(mean_distance_error_laser[0]/num_simu)) - 100), dec)) + "%\n")
results.write("mean Distance position error_marker: " + str(round(((((mean_distance_error_hybrid[0]/num_simu) * 100)/(mean_distance_error_RGB[0]/num_simu)) - 100), dec)) + "%\n")
results.write("\n")
#results.write("mean YAW error_laser: " + str(round(((((mean_yaw_error_hybrid[0]/num_simu) * 100)/(mean_yaw_error_laser[0]/num_simu)) - 100), dec)) + "%\n")
results.write("mean YAW error_marker: " + str(round(((((mean_yaw_error_hybrid[0]/num_simu) * 100)/(mean_yaw_error_RGB[0]/num_simu)) - 100), dec)) + "%\n")
results.write("\n")
#results.write("mean X deviation_laser: " + str(round(((((mean_x_deviation_hybrid[0]/num_simu) * 100)/(mean_x_deviation_laser[0]/num_simu)) - 100), dec)) + "%\n")
results.write("mean X deviation_marker: " + str(round(((((mean_x_deviation_hybrid[0]/num_simu) * 100)/(mean_x_deviation_RGB[0]/num_simu)) - 100), dec))+ "%\n")
results.write("\n")
#results.write("mean Y deviation_laser: " + str(round(((((mean_y_deviation_hybrid[0]/num_simu) * 100)/(mean_y_deviation_laser[0]/num_simu)) - 100), dec)) + "%\n")
results.write("mean Y deviation_marker: " + str(round(((((mean_y_deviation_hybrid[0]/num_simu) * 100)/(mean_y_deviation_RGB[0]/num_simu)) - 100), dec)) + "%\n")
results.write("\n")




results.close()

# %%
"""results.write("#### max ####\n")
results.write("max X position error_laser: " + str(round(((((max_x_error_hybrid[0]/num_simu) * 100)/(max_x_error_laser[0]/num_simu)) - 100), dec)) + "%\n")
results.write("max X position error_marker: " + str(round(((((max_x_error_hybrid[0]/num_simu) * 100)/(max_x_error_RGB[0]/num_simu)) - 100), dec)) + "%\n")
results.write("\n")
results.write("max Y position error_laser: " + str(round(((((max_y_error_hybrid[0]/num_simu) * 100)/(max_y_error_laser[0]/num_simu)) - 100), dec))  + "%\n")
results.write("max Y position error_marker: " + str(round(((((max_y_error_hybrid[0]/num_simu) * 100)/(max_y_error_RGB[0]/num_simu)) - 100), dec))  + "%\n")
results.write("\n")
results.write("max Distance position error_laser: " + str(round(((((max_distance_error_hybrid[0]/num_simu) * 100)/(max_distance_error_laser[0]/num_simu)) - 100), dec)) + "%\n")
results.write("max Distance position error_marker: " + str(round(((((max_distance_error_hybrid[0]/num_simu) * 100)/(max_distance_error_RGB[0]/num_simu)) - 100), dec)) + "%\n")
results.write("\n")
results.write("max YAW error_laser: " + str(round(((((max_yaw_error_hybrid[0]/num_simu) * 100)/(max_yaw_error_laser[0]/num_simu)) - 100), dec)) + "%\n")
results.write("max YAW error_marker: " + str(round(((((max_yaw_error_hybrid[0]/num_simu) * 100)/(max_yaw_error_RGB[0]/num_simu)) - 100), dec)) + "%\n")
results.write("\n")
results.write("max X deviation_laser: " + str(round(((((max_x_deviation_hybrid[0]/num_simu) * 100)/(max_x_deviation_laser[0]/num_simu)) - 100), dec)) + "%\n")
results.write("max X deviation_marker: " + str(round(((((max_x_deviation_hybrid[0]/num_simu) * 100)/(max_x_deviation_RGB[0]/num_simu)) - 100), dec))+ "%\n")
results.write("\n")
results.write("max Y deviation_laser: " + str(round(((((max_y_deviation_hybrid[0]/num_simu) * 100)/(max_y_deviation_laser[0]/num_simu)) - 100), dec)) + "%\n")
results.write("max Y deviation_marker: " + str(round(((((max_y_deviation_hybrid[0]/num_simu) * 100)/(max_y_deviation_RGB[0]/num_simu)) - 100), dec)) + "%\n")
results.write("\n")

results.write("#### min ####")
results.write("min X position error_laser: " + str(round(((((min_x_error_hybrid[0]/num_simu) * 100)/(min_x_error_laser[0]/num_simu)) - 100), dec)) + "%\n")
results.write("min X position error_marker: " + str(round(((((min_x_error_hybrid[0]/num_simu) * 100)/(min_x_error_RGB[0]/num_simu)) - 100), dec)) + "%\n")
results.write("\n")
results.write("min Y position error_laser: " + str(round(((((min_y_error_hybrid[0]/num_simu) * 100)/(min_y_error_laser[0]/num_simu)) - 100), dec))  + "%\n")
results.write("min Y position error_marker: " + str(round(((((min_y_error_hybrid[0]/num_simu) * 100)/(min_y_error_RGB[0]/num_simu)) - 100), dec))  + "%\n")
results.write("\n")
results.write("min Distance position error_laser: " + str(round(((((min_distance_error_hybrid[0]/num_simu) * 100)/(min_distance_error_laser[0]/num_simu)) - 100), dec)) + "%\n")
results.write("min Distance position error_marker: " + str(round(((((min_distance_error_hybrid[0]/num_simu) * 100)/(min_distance_error_RGB[0]/num_simu)) - 100), dec)) + "%\n")
results.write("\n")
results.write("min YAW error_laser: " + str(round(((((min_yaw_error_hybrid[0]/num_simu) * 100)/(min_yaw_error_laser[0]/num_simu)) - 100), dec)) + "%\n")
results.write("min YAW error_marker: " + str(round(((((min_yaw_error_hybrid[0]/num_simu) * 100)/(min_yaw_error_RGB[0]/num_simu)) - 100), dec)) + "%\n")
results.write("\n")
results.write("min X deviation_laser: " + str(round(((((min_x_deviation_hybrid[0]/num_simu) * 100)/(min_x_deviation_laser[0]/num_simu)) - 100), dec)) + "%\n")
results.write("min X deviation_marker: " + str(round(((((min_x_deviation_hybrid[0]/num_simu) * 100)/(min_x_deviation_RGB[0]/num_simu)) - 100), dec))+ "%\n")
results.write("\n")
results.write("min Y deviation_laser: " + str(round(((((min_y_deviation_hybrid[0]/num_simu) * 100)/(min_y_deviation_laser[0]/num_simu)) - 100), dec)) + "%\n")
results.write("min Y deviation_marker: " + str(round(((((min_y_deviation_hybrid[0]/num_simu) * 100)/(min_y_deviation_RGB[0]/num_simu)) - 100), dec)) + "%\n")
results.write("\n")"""
